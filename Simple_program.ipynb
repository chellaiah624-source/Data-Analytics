# %% [markdown]
# <a href="https://colab.research.google.com/github/chellaiah624-source/Data-Analytics/blob/main/Simple_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Welcome",name)
greet("Students")
# Out:
# Welcome Students

# %%
def add(a,b):
  return a+b
result = add(10,20)
print(result)
# Out:
# 30

# %%
Mark1=int(input("Enter Mark 1:"))
Mark2=int(input("Enter Mark 2:"))
Mark3=int(input("Enter Mark 3:"))
Mark4=int(input("Enter Mark 4:"))
Mark5=int(input("Enter Mark 5:"))

Total=Mark1+Mark2+Mark3+Mark4+Mark5
Average=Total/5

print("Total:",Total)
print("Average:",Average)

if Average>=50:
  print("Pass")
else:
  print("fail")
# Out:
# Enter Mark 1:90
# Enter Mark 2:89
# Enter Mark 3:76
# Enter Mark 4:87
# Enter Mark 5:45
# Total: 387
# Average: 77.4
# Pass
