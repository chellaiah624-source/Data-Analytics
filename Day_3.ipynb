# %% [markdown]
# <a href="https://colab.research.google.com/github/chellaiah624-source/Data-Analytics/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int(input("Enter Number:"))
  print(num)
except:
  print("Invalid Input")
# Out:
# Enter Number:123
# 123

# %%
import numpy as np
marks = np.array([60,80,78,89])
print(marks)
# Out:
# [60 80 78 89]

# %%
import numpy as np
students = np.array([
    [60,90],
    [78,87],
    [67,60]
])
print(students)
# Out:
# [[60 90]
#  [78 87]
#  [67 60]]
